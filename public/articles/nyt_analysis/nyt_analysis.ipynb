# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 41.5 MB/s  0:00:00 eta 0:00:01
# ...

# %%
# !pip install kagglehub
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.4 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl.metadata (40 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl (173 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl (309 kB)
# ...
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# ...

# %%
# !pip install pandas
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# Using cached pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 23.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...

# %%
import pandas as pd

# %%
import kagglehub
nyt_raw = kagglehub.dataset_download("aryansingh0909/nyt-articles-21m-2000-present")
# Out:
# ...
# 100%|██████████| 875M/875M [00:38<00:00, 23.9MB/s]
# Extracting files...

# %%
# nyt = pd.read_parquet(nyt_raw)
# display(nyt.head())
# print(nyt.shape)

# import pyarrow.parquet as pq

# table = pq.read_table(nyt_raw, use_pandas_metadata=False)
# nyt = table.to_pandas()
# display(nyt.head())
# print(nyt.shape)

import pyarrow.parquet as pq

table = pq.read_table(nyt_raw)
nyt = table.to_pandas()
display(nyt.head())
print(nyt.shape)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[19], line 14
#      10 # print(nyt.shape)
#      11
#      12 import pyarrow.parquet as pq
#      13
# ---> 14 table = pq.read_table(nyt_raw)
#      15 nyt = table.to_pandas()
#      16 display(nyt.head())
#      17 print(nyt.shape)
#
# File ~/Code/neofanaro.io/.venv/lib/python3.14/site-packages/pyarrow/parquet/core.py:1891, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1879 def read_table(source, *, columns=None, use_threads=True,
# ...

# %%
nyt.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17370913 entries, 0 to 17370912
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   year     int64
#  1   title    str
#  2   excerpt  str
# dtypes: int64(1), str(2)
# memory usage: 397.6 MB

# %%
print(nyt.columns)
# Out:
# Index(['year', 'title', 'excerpt'], dtype='str')
